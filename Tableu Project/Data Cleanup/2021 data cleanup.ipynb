# %%
import pandas as pd
import numpy as np

# %%
#import csv for 2020
csv = "JC-202101-citibike-tripdata.csv"

# %%
#read 2020 csv
Bike_trip_jan21 = pd.read_csv(csv)

# %%
#renaming dataframes
Bike_trip_jan21_df = Bike_trip_jan21

# %%
#vieweing dataframe 
Bike_trip_jan21_df
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               266  2021-01-01 00:03:35.5100  2021-01-01 00:08:01.7770
# 1              1543  2021-01-01 00:23:32.9250  2021-01-01 00:49:16.0830
# 2              1461  2021-01-01 00:23:50.7940  2021-01-01 00:48:12.5660
# 3               793  2021-01-01 00:31:09.0770  2021-01-01 00:44:22.9430
# 4               596  2021-01-01 00:35:52.1900  2021-01-01 00:45:48.7740
# ...             ...                       ...                       ...
# 11619          2476  2021-01-31 20:16:05.4700  2021-01-31 20:57:22.0110
# 11620           147  2021-01-31 21:05:05.2090  2021-01-31 21:07:32.8660
# 11621           660  2021-01-31 21:06:23.5880  2021-01-31 21:17:23.8420
# 11622           384  2021-01-31 21:16:37.8220  2021-01-31 21:23:02.1240
# 11623           356  2021-01-31 23:24:50.8810  2021-01-31 23:30:47.3030
#
#        start station id start station name  start station latitude  \
# ...

# %%
#checking type of data in dataframe
Bike_trip_jan21_df.dtypes
# Out:
# tripduration                 int64
# starttime                   object
# stoptime                    object
# start station id             int64
# start station name          object
# start station latitude     float64
# start station longitude    float64
# end station id               int64
# end station name            object
# end station latitude       float64
# end station longitude      float64
# bikeid                       int64
# usertype                    object
# birth year                   int64
# gender                       int64
# dtype: object

# %%
Bike_2021_df=Bike_trip_jan21_df

# %%
#removing columns
del Bike_2021_df['usertype']

# %%
# Changing The Type of Values for the Gender Column to reassign genders
Bike_2021_df['gender'] = Bike_2021_df['gender'].astype(str)

# %%
# Changing the Numeric Gender Values to Actual Gender Values For The 2020 df
Gender_check_2021 = Bike_2021_df['gender']
Changed_2021_male = Gender_check_2021.replace('1', 'Male')
Changed_2021_female = Changed_2021_male.replace('2', 'Female')
Changed_2021_unknown = Changed_2021_female.replace('0', 'Unknown')
Bike_2021_df['gender'] = Changed_2021_unknown
Bike_2021_df
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               266  2021-01-01 00:03:35.5100  2021-01-01 00:08:01.7770
# 1              1543  2021-01-01 00:23:32.9250  2021-01-01 00:49:16.0830
# 2              1461  2021-01-01 00:23:50.7940  2021-01-01 00:48:12.5660
# 3               793  2021-01-01 00:31:09.0770  2021-01-01 00:44:22.9430
# 4               596  2021-01-01 00:35:52.1900  2021-01-01 00:45:48.7740
# ...             ...                       ...                       ...
# 11619          2476  2021-01-31 20:16:05.4700  2021-01-31 20:57:22.0110
# 11620           147  2021-01-31 21:05:05.2090  2021-01-31 21:07:32.8660
# 11621           660  2021-01-31 21:06:23.5880  2021-01-31 21:17:23.8420
# 11622           384  2021-01-31 21:16:37.8220  2021-01-31 21:23:02.1240
# 11623           356  2021-01-31 23:24:50.8810  2021-01-31 23:30:47.3030
#
#        start station id start station name  start station latitude  \
# ...

# %%
# Calculating Biker's Age's 
current_year = 2024

Birth_year_2021 = Bike_2021_df['birth year']
age = current_year - Birth_year_2021
Bike_2021_df['age'] = age

# %%
# Rearranging the Columns
Bike_2021_df_organized = Bike_2021_df[["bikeid",
                                       "gender",
                                       "birth year",
                                       "age",
                                       "tripduration",
                                       "start station id",
                                       "start station name",
                                       "start station latitude",
                                       "start station longitude",
                                       "starttime",
                                       "end station id",
                                       "end station name", 
                                       "end station latitude",
                                       "end station longitude",
                                       "stoptime"]]
Bike_2021_df_organized
# Out:
#        bikeid   gender  birth year  age  tripduration  start station id  \
# 0       42494     Male        1988   36           266              3273
# 1       45343   Female        1996   28          1543              3681
# 2       31794     Male        1995   29          1461              3681
# 3       42316  Unknown        1969   55           793              3185
# 4       32575  Unknown        1969   55           596              3639
# ...       ...      ...         ...  ...           ...               ...
# 11619   44852     Male        1958   66          2476              3187
# 11620   46538     Male        1972   52           147              3186
# 11621   44398   Female        1987   37           660              3211
# 11622   41400     Male        1989   35           384              3205
# 11623   43766     Male        1994   30           356              3639
#
#       start station name  start station latitude  start station longitude  \
# ...

# %%
# Renaming the Columns for consistency
Bike_2021_renamed_df = Bike_2021_df_organized.rename(columns={"bikeid":"Bike ID", 
                                                              "gender":"Gender",
                                                              "birth year":"Birth Year",
                                                              "age":"Age",
                                                              "tripduration":"Trip Duration",
                                                              "start station id":"Start Station ID",
                                                              "start station name":"Start Station Name",
                                                              "start station latitude":"Start Station Latitude",
                                                              "start station longitude":"Start Station Longitude",
                                                              "starttime":"Start Time",
                                                              "end station id":"End Station ID",
                                                              "end station name":"End Station Name",
                                                              "end station latitude":"End Station Latitude",
                                                              "end station longitude":"End Station Longitude",
                                                              "stoptime":"Stop Time"})
Bike_2021_renamed_df.dropna
# Out:
# <bound method DataFrame.dropna of        Bike ID   Gender  Birth Year  Age  Trip Duration  Start Station ID  \
# 0        42494     Male        1988   36            266              3273
# 1        45343   Female        1996   28           1543              3681
# 2        31794     Male        1995   29           1461              3681
# 3        42316  Unknown        1969   55            793              3185
# 4        32575  Unknown        1969   55            596              3639
# ...        ...      ...         ...  ...            ...               ...
# 11619    44852     Male        1958   66           2476              3187
# 11620    46538     Male        1972   52            147              3186
# 11621    44398   Female        1987   37            660              3211
# 11622    41400     Male        1989   35            384              3205
# 11623    43766     Male        1994   30            356              3639
#
# ...

# %%
# Outputting file to csv 
Bike_2021_renamed_df.to_csv("2021_citibike_tripdata_cleaned.csv", index=False, header=True)
